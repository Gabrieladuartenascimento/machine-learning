# %%
# !pip uninstall -y tensorflow
# Out:
# Found existing installation: tensorflow 2.8.2+zzzcolab20220527125636
# Uninstalling tensorflow-2.8.2+zzzcolab20220527125636:
#   Successfully uninstalled tensorflow-2.8.2+zzzcolab20220527125636

# %%
# !pip install gast==0.3.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for gast: filename=gast-0.3.2-py3-none-any.whl size=9694 sha256=ff9d533cc888e2b180a5dbb68a6fa31404fdffc53bea41b71c046170c6b2aef6
#   Stored in directory: /root/.cache/pip/wheels/9b/7b/89/365a82e420c11db9b43d34918045faa8004748a1d97597930d
# Successfully built gast
# ...
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
# ...

# %%
# !pip install tensorflow-gpu==2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 380.8 MB 35 kB/s
# ...
#      |████████████████████████████████| 50 kB 3.6 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 57.7 MB/s
# ...
#      |████████████████████████████████| 449 kB 56.1 MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=e9039faba746c4470c93b3e656021c3732f7f07ff9a4161fb821992eaa37a648
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
# ...

# %%
import numpy as np
import datetime
import tensorflow as tf
import seaborn as sns

# %%
dataset = sns.load_dataset('iris')

# %%
dataset.loc[dataset["species"]=="setosa","species"]=0
dataset.loc[dataset["species"]=="versicolor","species"]=1
dataset.loc[dataset["species"]=="virginica","species"]=2

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-733ec01447a1> in <module>()
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)
#
# NameError: name 'X' is not defined

# %%
X = dataset[['sepal_length','sepal_width','petal_length','petal_width']].values
y = dataset['species'].values.astype('float32')

# %%
RNA_modelo = tf.keras.models.Sequential()

# %%
RNA_modelo.add(tf.keras.layers.Dense(units=80, activation='relu', input_dim=4))
RNA_modelo.add(tf.keras.layers.Dropout(0.3))
RNA_modelo.add(tf.keras.layers.Dense(units=10, activation= 'softmax'))
RNA_modelo.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy')

# %%
RNA_modelo.fit(X_train, y_train, epochs=10)

# %%
y_pred = RNA_modelo.predict(X_test)

# %%
 score = RNA_modelo.evaluate(X_test, y_test, verbose=1)

# %%
 print("Test Accuracy:", score)
